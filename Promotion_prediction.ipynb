# %% [markdown]
# # Employee_Promotion_Prediction

# %% [markdown]
# Goal:
# You want to find which features are most helpful in predicting whether an employee gets promoted.

# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("Downloads/train_utf8.csv")
data.head(10)
# The target column is the is_promoted coulmn. the column is binary and specifies whether the 
# employee was promoted or not.
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
# 5        58896          Analytics   region_2        Bachelor's      m
# 6        20379         Operations  region_20        Bachelor's      f
# 7        16290         Operations  region_34  Master's & above      m
# 8        73202          Analytics  region_20        Bachelor's      m
# 9        28911  Sales & Marketing   region_1  Master's & above      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# ...

# %%
data.describe()
# Describing the statistical data(mean,median,std,min,max,count)
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
data.info()
# info: gives the information about the data.and also dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
# number of unique values in the dataset.
data.nunique()
# Out:
# employee_id             54808
# department                  9
# region                     34
# education                   3
# gender                      2
# recruitment_channel         3
# no_of_trainings            10
# age                        41
# previous_year_rating        5
# length_of_service          35
# KPIs_met >80%               2
# awards_won?                 2
# avg_training_score         61
# is_promoted                 2
# dtype: int64

# %%
data.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
# renaming the columns
cols=['employee_id', 'department', 'region', 'education', 'gender',
       'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
       'length_of_service', 'KPIs_met', 'awards_won',
       'avg_training_score', 'is_promoted']
data.columns=cols

# %%
data.columns
# columns: gives the columns present in the dataset.
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met', 'awards_won', 'avg_training_score',
#        'is_promoted'],
#       dtype='object')

# %%
# defines the number of rows and columns in the dataset.
data.shape
# Out:
# (54808, 14)

# %%
plt.figure(figsize=(16,12))
plt.subplot(2,1,1)
sns.countplot(x="region",hue="is_promoted",data=data)
plt.xticks(rotation=90)

plt.subplot(2,1,2)
sns.countplot(x="department",hue="is_promoted",data=data)
plt.show()

#employees in the Sales and Marketing department and those based in Region 2 were promoted more frequently than those in other groups. 
# but they arent highly correlated with the target_variable.

# %%
# # dropping the columns which are not in use like employee_id it consists of the unique values.
# data.drop(["region"],axis=1,inplace=True)
# data.columns

# %%
data["is_promoted"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# checking the null values.
data.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met                   0
# awards_won                 0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
data.education.count()
# Out:
# 52399

# %%
data.education.unique()
# Out:
# array(["Master's & above", "Bachelor's", nan, 'Below Secondary'],
#       dtype=object)

# %%
data["education"].mode()
# Out:
# 0    Bachelor's
# Name: education, dtype: object

# %%
# fillling null values in education with the mode.
data["education"]=data["education"].fillna(data["education"].mode()[0])
data["education"].unique()
# Out:
# array(["Master's & above", "Bachelor's", 'Below Secondary'], dtype=object)

# %%
data.previous_year_rating.unique()
# Out:
# array([ 5.,  3.,  1.,  4., nan,  2.])

# %%
data.previous_year_rating.isnull().sum()
# Out:
# 4124

# %%
data[data.length_of_service == 1]
# Here when the length_of_service is "1" the previous_year_rating is "NAN".
# the previous_year_ratings are filled with 0, making it the lowest score as well as indicating absence of value (rating) all together.
# Out:
#        employee_id         department     region   education gender  \
# 10           29934         Technology  region_23  Bachelor's      m
# 23           71177        Procurement   region_5  Bachelor's      m
# 29           74759  Sales & Marketing   region_4  Bachelor's      m
# 56           45709  Sales & Marketing  region_31  Bachelor's      f
# 58           26599  Sales & Marketing  region_16  Bachelor's      m
# ...            ...                ...        ...         ...    ...
# 54703        74615                R&D  region_31  Bachelor's      m
# 54734        11685         Operations  region_15  Bachelor's      m
# 54746        10546            Finance   region_6  Bachelor's      m
# 54773        37919            Finance   region_2  Bachelor's      m
# 54801        12431         Technology  region_26  Bachelor's      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 10               sourcing                1   30                   NaN
# ...

# %%
data["previous_year_rating"]=data["previous_year_rating"].fillna(0) #missing values are filled with "0"s
data["previous_year_rating"].unique()
# Out:
# array([5., 3., 1., 4., 0., 2.])

# %%
data.isnull().sum()
# we dont have any null values in the data-set.
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met                0
# awards_won              0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
# the distribution chart for the age and the promoted values..

sns.displot(data=data,x="age",hue="is_promoted",kind="hist",multiple="stack", palette={0: 'skyblue', 1: 'orange'})
plt.xticks(ticks=[20, 30, 40, 50, 60], labels=['20s', '30s', '40s', '50s', '60s'])
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title("Age Vs Promotion-Status")
plt.show()

# %% [markdown]
# * Most employees are in their 30s, followed by 40s and late 20s.
# * The orange bars (promoted employees) are a small portion compared to blue bars (non-promoted).
# * Promotions happen more frequently in the 30–40 age range, but the total promoted population is low.

# %%
sns.countplot(x="is_promoted",data=data)
plt.show()

# %%
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(16,10))
for i,col in enumerate(numerical_cols):
    plt.subplot(4,3,i+1)
    sns.histplot(data[col],kde=True)
    plt.title(col)
plt.show()

# %% [markdown]
# 1. no_of_trainings: Skewed heavily to the left: Most people took very few trainings (mostly 1).
# 2. Age: Bell-shaped distribution centered around 30–35.(close to normal distribution)
# 3. Previous_year_rating: A spike around 3 or 4 suggests most employees got mid-to-high ratings.(from 1 to 5)
# 4. length_of_service: Skewed right Majority have shorter service durations.
# 5. KPIs_met: Most employees did meet their KPIs.
# 6. awards_won: Most employees did not win the awards.
# 7. is_promoted: it is highly imbalanced.most employees are not employees.
# 8. avg_training_score: scores are between 50 and 90..
#
# * Imbalanced features like is_promoted, awards_won?, and KPIs_met >80% can affect ML model performance and may need resampling (e.g., SMOTE or undersampling).
# * Highly skewed features (like no_of_trainings and length_of_service) might need transformation (e.g., log scaling) for some algorithms.
# * Distribution of avg_training_score could indicate different training impact groups.
# * age and avg_training_score appear more normally distributed and can be treated differently from binary/skewed ones.

# %%
plt.figure(figsize=(8,8))

# Awards_won
plt.subplot(2,2,1)
sns.countplot(data=data,x="awards_won",hue="is_promoted")
plt.title("Awards_won")

# KPIs_met
plt.subplot(2,2,2)
sns.countplot(data=data,x="KPIs_met",hue="is_promoted")
plt.title("KPIs_met")

plt.subplot(2,2,3)
sns.countplot(data=data,x="education",hue="is_promoted")
plt.xticks(rotation=70)
plt.title("Education")

plt.show()

# %% [markdown]
# From Awards_Won:
# * Most employees did not win awards.Those who are promoted,a higher proportion won awards compared to those who weren't.
# so there is slight chance of promotion if employee has won the award
#
# From KPIs_met:
# * A maximum number of employees who were promoted had met KPIs. Most people who haven't met KPIs_met are not promoted.
# The KPIs_met strongly related with being promoted
#
# from Education:
# * Education level shows influence, but Bachelor’s and Master’s degrees are the most common among employees.
# While higher education (Bachelor's or Master’s) may help, it does not guarantee promotion.

# %%
data["total_score"]=data.no_of_trainings * data.avg_training_score
data.head()
# total_score is an entry based on how many trainings were attended and how well the person performed on average.
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met  awards_won  avg_training_score  is_promoted  \
# ...

# %%
# lets divide the total_score into 3 categories "high","medium","low" based on values 0-65(low), 65-145 (medium),>145 (Higher)

data["total_score_label"]=pd.cut(data.total_score,bins=[0,65,145,1000],labels=["low","Medium","High"])
data.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met  awards_won  avg_training_score  is_promoted  \
# ...

# %%
scores=data.pivot_table(values="is_promoted",index="total_score_label",observed=False)
scores
# Out:
#                    is_promoted
# total_score_label
# low                   0.057549
# Medium                0.117858
# High                  0.097444

# %%
plt.figure(figsize=(8,8))
plt.bar(scores.index,scores.is_promoted,color=["lightgreen","skyblue","lightpink"])
plt.xlabel("Scores")
plt.ylabel("Number of Promoted employees")
plt.show()

# %% [markdown]
# * conclusion from the plot is :
#  Employees promoted have scores in the Medium and High range i.e. 65 and greater
#  Medium score level having the highest percentage of promoted employees means
#  total score is not the only criterion for promotion.

# %%
data.length_of_service.unique()
# Out:
# array([ 8,  4,  7, 10,  2,  5,  6,  1,  3, 16,  9, 11, 26, 12, 17, 14, 13,
#        19, 15, 23, 18, 20, 22, 25, 28, 24, 31, 21, 29, 30, 34, 27, 33, 32,
#        37], dtype=int64)

# %%
data["service_years"]=pd.cut(data.length_of_service,bins=[0,2,7,13,37],labels=["Beginner", "Growing", "Skilled", "Expert"])
data.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met  awards_won  avg_training_score  is_promoted  \
# ...

# %%
service=data.pivot_table(values="is_promoted",index="service_years",observed=False)
service
# Out:
#                is_promoted
# service_years
# Beginner          0.086546
# Growing           0.084940
# Skilled           0.090576
# Expert            0.067068

# %%
# plotting the bar graph for the service_years
plt.figure(figsize=(8,8))
plt.bar(service.index,service['is_promoted'],color=['skyblue','lightgreen', 'orange', 'tomato'])
plt.title("Service_years")
plt.show()

# %% [markdown]
# * The plot above concludes that :-
#
# * Skilled employees are likely to get promoted than other categories, due to their experience and understanding of the company
# Beginner and Growing employees have almost equal likelihood of getting promoted.
# Expert employees generally get less promotions. Due to their number of years given to the company, majority of them might have reached the success.

# %%
data.gender.value_counts()
# Out:
# gender
# m    38496
# f    16312
# Name: count, dtype: int64

# %%
data.age.unique()
# Out:
# array([35, 30, 34, 39, 45, 31, 33, 28, 32, 49, 37, 38, 41, 27, 29, 26, 24,
#        57, 40, 42, 23, 59, 44, 50, 56, 20, 25, 47, 36, 46, 60, 43, 22, 54,
#        58, 48, 53, 55, 51, 52, 21], dtype=int64)

# %%
data.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met', 'awards_won', 'avg_training_score',
#        'is_promoted', 'total_score', 'total_score_label', 'service_years'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
Gender_le=LabelEncoder()
Dept_le =LabelEncoder()
Region_le=LabelEncoder()
Education_le=LabelEncoder()

# Fit and transform each columns
data["gender"]=Gender_le.fit_transform(data["gender"])
data["department"]=Dept_le.fit_transform(data["department"])
data["region"]=Region_le.fit_transform(data["region"])
data["education"]=Education_le.fit_transform(data["education"])


# print(data["Gender"].unique())
# print(Gender_le.classes_)
# print(data["Region"].unique())
# print(Region_le.classes_)
# print(Dept_le.classes_)
# print(data["Department"].unique())
# print(Education_le.classes_)
# print(data["Education"].unique())

# %%
data.drop(["employee_id","recruitment_channel","total_score_label","service_years"],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['department', 'region', 'education', 'gender', 'no_of_trainings', 'age',
#        'previous_year_rating', 'length_of_service', 'KPIs_met', 'awards_won',
#        'avg_training_score', 'is_promoted', 'total_score'],
#       dtype='object')

# %%
corr=data.corr(numeric_only=True)
corr
# Out:
#                       department    region  education    gender  \
# department              1.000000 -0.020592   0.043441 -0.030108
# region                 -0.020592  1.000000  -0.003815  0.019730
# education               0.043441 -0.003815   1.000000 -0.032368
# gender                 -0.030108  0.019730  -0.032368  1.000000
# no_of_trainings         0.014152 -0.004590  -0.033469  0.084501
# age                     0.079162 -0.088918   0.339966 -0.016293
# previous_year_rating   -0.100340 -0.013465   0.092379 -0.025053
# length_of_service       0.059060 -0.058939   0.233666 -0.019675
# KPIs_met               -0.088209 -0.007664   0.012123 -0.037400
# awards_won             -0.002151  0.000307  -0.001409  0.002381
# avg_training_score     -0.251626  0.023572   0.032787 -0.024494
# is_promoted             0.000130  0.008841   0.029257 -0.011109
# total_score            -0.096808  0.004679  -0.018325  0.066472
#
# ...

# %% [markdown]
# from the heatmap:
# * no_of_trainings and total_score = 0.90(closer to one.) are correlated with each other..
# * length_of_Service and age are closer to zero.and gender is not highly correlated with target varaible.
# * previous_year_rating,KPIs_met,awards_won,avg_training_Score are highly correlated with the is_promoted column, from the dataset.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,cmap="Greens")
plt.show()

# %% [markdown]
# the target variable is highly correlated correlated with the 'KPIs_met', 'awards_won', 'avg_training_score', 'previous_year_rating'

# %%
data["is_promoted"].value_counts()
# Here the data is imbalanced.
# Out:
# is_promoted
# 0    50140
# 1     4668
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler


# Original data
X = data.drop("is_promoted",axis=1)
y = data['is_promoted']

ros=RandomOverSampler(random_state=1)
X_res,y_res=ros.fit_resample(X,y)
print(X_res.shape)
print(y_res.value_counts())
# Out:
# (100280, 12)
# is_promoted
# 0    50140
# 1    50140
# Name: count, dtype: int64

# %%
# Train-test split on original data
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score,accuracy_score,classification_report,confusion_matrix


lr = LogisticRegression(class_weight="balanced",max_iter=1000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
# RandomClassifier..
rf=RandomForestClassifier(n_estimators=100,class_weight="balanced")
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
# XGB Classifier..
xgb=XGBClassifier(n_estimators=100,use_label_encoder=False,eval_metric='logloss')
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# Evaluation

for model in [lr,rf,xgb]:
    y_pred=model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]
    print(model.__class__.__name__,"\n")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("AUC-ROC:", roc_auc_score(y_test, y_prob))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("\n")
# Out:
# LogisticRegression
#
# Accuracy: 0.7220283207020343
# AUC-ROC: 0.803105532641012
# Confusion Matrix:
#  [[7220 2977]
#  [2598 7261]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.71      0.72     10197
#            1       0.71      0.74      0.72      9859
#
#     accuracy                           0.72     20056
#    macro avg       0.72      0.72      0.72     20056
# weighted avg       0.72      0.72      0.72     20056
#
#
#
# RandomForestClassifier
#
# Accuracy: 0.9836956521739131
# AUC-ROC: 0.999667962181638
# Confusion Matrix:
#  [[9870  327]
#  [   0 9859]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     10197
#            1       0.97      1.00      0.98      9859
#
#     accuracy                           0.98     20056
#    macro avg       0.98      0.98      0.98     20056
# ...

# %%
y_prob = model.predict_proba(X_test)[:, 1]
y_prob
# Out:
# array([0.99781466, 0.9876945 , 0.04902244, ..., 0.01225424, 0.7993707 ,
#        0.22037269], dtype=float32)

# %%
models = [rf, xgb, lr]
model_names = ['Random Forest', 'XGBoost', 'Logistic Regression']

plt.figure(figsize=(15, 4))

for i, model in enumerate(models):
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    
    plt.subplot(1, 3, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'{model_names[i]}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')

plt.suptitle('Confusion Matrices Comparison')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve,auc
plt.figure(figsize=(8, 6))

for model in [rf, xgb, lr]:
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'{model.__class__.__name__} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid()
plt.tight_layout()

plt.show()

# %%
feature_cols=data.drop("is_promoted",axis=1)

is_promoted_pred = model.predict(feature_cols)
is_promoted_pred = (model.predict_proba(feature_cols)[:, 1] > 0.5).astype(int)
#threshold value is 0.5

# %%
df=pd.read_csv("Downloads/train_utf8.csv")
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
submission = pd.DataFrame({
    'employee_id': df['employee_id'],
    'is_promoted': is_promoted_pred
})
submission
# Out:
#        employee_id  is_promoted
# 0            65438            1
# 1            65141            0
# 2             7513            0
# 3             2542            0
# 4            48945            0
# ...            ...          ...
# 54803         3030            0
# 54804        74592            0
# 54805        13918            1
# 54806        13614            0
# 54807        51526            0
#
# [54808 rows x 2 columns]

# %%
submission.to_csv('submission_file.csv', index=False)
# checking the file .
import os

if os.path.isfile('submission_file.csv'):
    print("File saved successfully!")
else:
    print("File not found.")
# Out:
# File saved successfully!

# %%
pd.read_csv('submission_file.csv').head()
# Out:
#    employee_id  is_promoted
# 0        65438            1
# 1        65141            0
# 2         7513            0
# 3         2542            0
# 4        48945            0

# %%
import joblib
joblib.dump(model,r"C:\Users\mutyalasravanthi\OneDrive\Desktop\Employ_analysis\model.h5")
# Out:
# ['C:\\Users\\mutyalasravanthi\\OneDrive\\Desktop\\Employ_analysis\\model.h5']

# %%
# joblib.dump()
